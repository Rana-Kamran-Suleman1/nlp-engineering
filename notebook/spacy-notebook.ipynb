# %%
import spacy

# %%
nlp = spacy.load("en_core_web_md")

# %%
doc=nlp("Hello Words First Program is Running")

# %%
for token in doc:
    print(token.text)
# Out:
# Hello
# Words
# First
# Program
# is
# Running

# %%
print(nlp.Defaults.stop_words)
print(len(nlp.Defaults.stop_words))
# Out:
# {'into', 'where', 'could', 'myself', 'wherever', 'do', 'show', 'most', 'therefore', 'yours', 'amount', 'done', 'whither', 'whom', 'used', 'elsewhere', 'keep', 'still', 'themselves', 'anyway', 'anywhere', 'when', 'about', 'nowhere', 'before', 'make', 'already', 'side', 'after', 'everyone', 'fifty', 'thereafter', 'below', 'since', 'these', 'can', 'thereupon', 'behind', 'please', 'same', 'always', 'its', 'am', 'those', 'might', 'while', 'front', '’s', 'upon', 'go', 'twelve', 'everywhere', 'your', 'whenever', 'noone', 'others', 'whereas', 'seeming', 'she', 'you', 'sometime', 'four', 'along', 'sixty', 'whereupon', 'mine', 'none', "'d", 'whence', '’ll', 'must', 'least', 'but', 'seem', 'though', 'besides', 'become', 'six', "'re", 'say', 'whoever', 'over', 'not', 'if', "'ll", 'often', 'beforehand', 'to', 'in', 'off', 'via', 'been', 'back', 'neither', 'which', 'itself', 'no', 'are', 'than', 'using', 'throughout', 'on', 'take', 'each', 'across', 'many', 'eight', 'three', 'it', 'cannot', 'above
# ...

# %%
#Stemming

#Lemmatization
